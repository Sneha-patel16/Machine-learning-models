# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, ExtraTreesClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# Read Data

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded.keys())
# Out:
#      <input type="file" id="files-85aa8b68-2d11-4d40-9121-d9ee2c6dda81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85aa8b68-2d11-4d40-9121-d9ee2c6dda81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Titanic-Dataset.csv')
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 366          367         1       1
# 71            72         0       3
# 774          775         1       2
# 325          326         1       1
# 213          214         0       2
# 692          693         1       3
# 334          335         1       1
# 273          274         0       1
# 421          422         0       3
# 609          610         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 71                          Goodwin, Miss. Lillian Amy  female  16.0      5
# 774              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1
# 325                           Young, Miss. Marie Grice  female  36.0      0
# 213                        Givard, Mr. Hans Kristensen    male  30.0      0
# 692                                       Lam, Mr. Ali    male   NaN      0
# ...

# %% [markdown]
# Cheak Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Display Information of Data

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Found a Missing Value.

# %%
df.isna().sum().sum().item()
# Out:
# 866

# %% [markdown]
# The Sum of a Missing Value.

# %%
df.duplicated().sum().item()
# Out:
# 0

# %% [markdown]
# Not Found Duplicate Value

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# Data cleaning

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Embarked"].replace(["C","S","Q"],["Cherbourg","Southampton","Queenstown"])
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: Embarked, Length: 891, dtype: object

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Survived",data=df)
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Survived",data=df, hue="Sex",palette="rainbow")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Pclass",data=df, hue="Survived",palette="brg")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Embarked",data=df, hue="Survived",palette="brg")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.countplot(x="Embarked",data=df, hue="Pclass",palette="rainbow")
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.histplot(x="Age",data=df,palette="rainbow")
plt.show()
# Out:
# <ipython-input-48-600389c4772b>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x="Age",data=df,palette="rainbow")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.figure(figsize=(10,5))
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap(numeric_df.corr(),annot=True)
plt.show()

# %% [markdown]
# CONCLUSION:-

# %% [markdown]
# Analysis of the Titanic dataset reveals that gender, passenger class, and age were key factors influencing survival. Women, first-class passengers, and younger individuals had higher survival rates. These insights highlight the social and economic disparities prevalent during the disaster and underscore the importance of data analysis in understanding historical events.
#
# I have tried to summarize the key findings and their significance in a more concise manner. Let me know if you'd like any further refinements!
